# %%
# General Modules
import re
import pandas as pd
import matplotlib.pyplot as plt
import os

# Modules Related to PDF Pre-Processing
import fitz
import os
import pdfplumber
from PyPDF2 import PdfReader, PdfWriter
from fpdf import FPDF
import PIL.Image

# Modules Related to PDF Processing
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import Chroma

from langchain import PromptTemplate
from langchain.chains.question_answering import load_qa_chain
from langchain.chains import RetrievalQA,StuffDocumentsChain ,LLMChain
# Modules Related to SQL Processing 
import psycopg2
import urllib
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import SQLDatabaseToolkit
from langchain.agents import create_sql_agent
from langchain.agents.agent_types import AgentType
from statsmodels.tsa.arima.model import ARIMA
from langchain.vectorstores import FAISS
from langchain.document_loaders import UnstructuredExcelLoader
import google.generativeai as genai
from langchain_google_genai import GoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# 2.Gemini API Key
GOOGLE_API_KEY = 'AIzaSyBIBaI7Cr-bINi-cRK9BHa2rUMK2MpqONQ'
# Define Model and Embedding Model
model = GoogleGenerativeAI(model="gemini-pro", temperature=0.3, google_api_key=GOOGLE_API_KEY)
chat_model = ChatGoogleGenerativeAI(model="gemini-pro",google_api_key=GOOGLE_API_KEY,)
embeddings = GoogleGenerativeAIEmbeddings(model = "models/embedding-001",google_api_key=GOOGLE_API_KEY)


def get_sql_query_from_excel(file_name1,query):  
    path=os.getcwd()
    print("current path File--->",path)
    file_path=os.path.join(path,file_name1)
    loaders = [UnstructuredExcelLoader(file_path)]

    print("loaders--->",loaders)

    docs = []
    for loader in loaders:
        docs.extend(loader.load())
    
    print("docs--->",docs)
    print()
    vectorstore_db = FAISS.from_documents(docs,embeddings)
    embeddings_vector = embeddings.embed_query(query)
    docs = vectorstore_db.similarity_search_by_vector(embeddings_vector)

    prompt_template = """
    You are the best in reading the excel sheet and summarize about the soure,sink ids and extract available and connected states of the sink ids and source ids.
    If the user asks any kind of summary related question then you should return the answer in a formatted way with in depth answer of everything with the values
    if the question is related to connection states - search the excel for keywords like CS_CONNECTING,CS_CONNECTED.
    if the question is related to connection IDs - search the keywords 'ConnectionID','MainConn ID','mainConnectionID'
    if the question is realted to available and unavailable state od source ans sink ids - then search or consider keywords 'isavail','available',
    'isSinkAvailable()',''not avail''.
    if there is no answers in the context just give response "please refer the logs"\n\n
 
   
    Context:\n {context}?\n
    Question: \n{question}\n
    Answer:
    """
    
    
    
    context = docs
    prompt = PromptTemplate(template = prompt_template, input_variables = ["context", "question"])
    qa_retreival = LLMChain(llm=chat_model,prompt=prompt,return_final_only=True)
    response = qa_retreival.invoke({"context": context, "question": query})
    response = response["text"]
    return response

    
    context = docs
    prompt = PromptTemplate(template = prompt_template, input_variables = ["context", "question"])
    qa_retreival = LLMChain(llm=chat_model, prompt=prompt, return_final_only=True)
    response = qa_retreival.invoke({"context": context, "question": query})
    response = response["text"]
    return response

# %%
def get_description(file_name2,query):
    print("File2---->",file_name2)
    loaders = [UnstructuredExcelLoader(file_name2)]
    print("loaders--->",loaders)


    docs = []
    for loader in loaders:
        docs.extend(loader.load())
    vectorstore_db = FAISS.from_documents(docs,embeddings)
    embeddings_vector = embeddings.embed_query(query)
    docs = vectorstore_db.similarity_search_by_vector(embeddings_vector)
    prompt_template = """
    You are the best in reading the excel sheet give descriptions of sink ids and source ids.
    if there is no answers in the context just reply "Answer is not available in the provided context"\n\n

    
    Context:\n {context}?\n
    Question: \n{question}\n 
    Answer: 
    """
    context = docs[:2]
    prompt = PromptTemplate(template = prompt_template, input_variables = ["context", "question"])
    qa_retreival = LLMChain(llm=chat_model,prompt=prompt)
    response = qa_retreival.invoke({"context": context, "question": query})
    response = response["text"]
    return response

# %%
def query_agent(query):
    prompt = (
        """
            if the query contains the word "DESCRIPTION" or "desc"
            for example: what is the description of id = 647? or "what is id=647"
            return 'description'; 
            else:
            return 'status'. 
            Below is the query.
            Query: 
            """ +
       
         query
    )
    # model = GoogleGenerativeAI(model="gemini-pro", temperature=0.3, google_api_key=GOOGLE_API_KEY)
    response = chat_model.invoke(prompt)
    return response

# %%
from flask import Flask, request, jsonify
from flask_cors import CORS
import warnings
app = Flask(__name__)
CORS(app)

file1_name=None
file2_name=None

@app.route('/receive_data_final_final2', methods=['POST'])
def receive_data():
    global file1_name,file2_name
    try:
        if request.method == 'POST':

            received_data = request.json  # Get the JSON data sent from frontend
            print("received_data----->", received_data)
            
            if "files" in received_data:
                
                file_names = received_data.get('files', [])
                print("Received file names:", file_names)
                
                file1_name=[files for files in file_names if files.startswith("Log")][0]
                file2_name= [files for files in file_names if not files.startswith("Log")][0]
                
                print("file1_namefile2_name-------->",file1_name,file2_name)
                
                return jsonify({"message": "File names received successfully", "file_names": file_names}), 200

                
            if "message" in received_data:
                
            
                print("received_data----->", received_data)
                print("received_data sample", received_data["message"])  # Print received data for testing purposes

                user_question = received_data["message"]
                print("user question",user_question)

                question_source = query_agent(user_question)
                pattern = 'status'
                match = re.search(pattern, str(question_source), re.IGNORECASE)
                if match:
                    log_file=file1_name
                    print("log_file------->",log_file)

                    agent_output=get_sql_query_from_excel(file1_name,user_question)
                    print("output--->",agent_output)
                    received_data.update({'role': 'assistant', 'content': agent_output})
                else:
                    print("Description----->")
                    description_file=file2_name
                    print("description_file------->",file2_name)
                    result=get_description(file2_name,user_question)
                    print("final result->",result)


                    received_data.update({'role': 'assistant', 'content2': result,'error':"error"})
                return jsonify(received_data)



    except Exception as e:
            print("Error:", e)
            print("received_data final2 ----->", received_data)
            return jsonify({"message": "Error processing data"}), 500
 
 
if __name__ == '__main__':
    app.run(host='127.0.0.1', port=9008, debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:9008
# Press CTRL+C to quit
# 127.0.0.1 - - [27/Aug/2024 15:12:16] "OPTIONS /receive_data_final_final2 HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Aug/2024 15:12:16] "POST /receive_data_final_final2 HTTP/1.1" 200 -
# received_data-----> {'files': ['Combined.xlsx', 'Logs.xlsx']}
# Received file names: ['Combined.xlsx', 'Logs.xlsx']
# file1_namefile2_name--------> Logs.xlsx Combined.xlsx
# 127.0.0.1 - - [27/Aug/2024 15:12:21] "OPTIONS /receive_data_final_final2 HTTP/1.1" 200 -
# received_data-----> {'message': 'What is the connection status along with source and sink ids for the different connetions in\xa0 bullet points?'}
# received_data-----> {'message': 'What is the connection status along with source and sink ids for the different connetions in\xa0 bullet points?'}
# received_data sample What is the connection status along with source and sink ids for the different connetions in  bullet points?
# user question What is the connection status along with source and sink ids for the different connetions in  bullet points?
# log_file-------> Logs.xlsx
# current path File---> C:\Users\40019115\BMW_Files_Final\Backend
# loaders---> [<langchain_community.document_loaders.excel.UnstructuredExcelLoader object at 0x00000195A323CA90>]
# docs---> [Document(page_content='\n\n\nId\nTimestamp\nDate\nMonth\nYear\nReference\nDescription\n\n\n4252\n2024-01-19 23:34:19.988000\n19\n1\n2024\n4641.2925\n\n\n\n42544\n2024-01-19 23:34:19.988000\n19\n1\n2024\n4641.2925\nMGUL NSM LCMG 922 log info verbose 1 leaving Startup\n\n\n799244\n2024-01-19 23:34:20.204000\n19\n1\n2024\n4641.3887\n7 MGUL AUDI RSL 42 log info verbose 11 registerDomain DomainID: 2 Name: DOMAIN_MGU Early: false State: 1 Instance: DOMAIN_MGU\n\n\n88815\n2024-01-19 23:34:25.805000\n19\n1\n2024\n4645.284\nMGUL AUDI RSL 42 log info verbose 11 registerDomain DomainID: 1 Name: DOMAIN_RAM Early: true State: 2 Instance: 1\n\n\n88859\n2024-01-19 23:34:25.807000\n19\n1\n2024\n4645.2861\nMGUL AUDI ASM 42 log info verbose 3 [SM] Lifecycle: s_RAM_Domain_Independend_Startup\n\n\n88861\n2024-01-19 23:34:25.807000\n19\n1\n2024\n4645.2862\nMGUL AUDI RSCA 42 log info verbose 5 setDomainState DomainID 1 State DS_CONTROLLED\n\n\n106351\n2024-01-19 23:34:26.948000\n19\n1\n2024\n4647.9275\nMGUL NSM LCMG 922 log info verbose 3 entering WELCOME_SCREEN 90\n\n\n107188\n2024-01-19 23:34:27.001000\n19\n1\n2024\n4647.9808\nMGUL NSM LCMG 922 log info verbose 3 entering ENTERTAINMENT 100\n\n\n107232\n2024-01-19 23:34:27.003000\n19\n1\n2024\n4647.9829\nMGUL AUDI AEVE 42 log info verbose 4 New Mainconnection: ConnectionID 70, SourceID 129, SinkID 387\n\n\n107511\n2024-01-19 23:34:27.019000\n19\n1\n2024\n4648.008\nMGUL AUDI AMC 42 log info verbose 5 MediaSinkFront1024::sendConnectionRequest(): Connection Request 1 to 1024\n\n\n107513\n2024-01-19 23:34:27.019000\n19\n1\n2024\n4648.0083\nMGUL AUDI AEVE 42 log info verbose 4 New Mainconnection: ConnectionID 72, SourceID 1, SinkID 1024\n\n\n107528\n2024-01-19 23:34:27.020000\n19\n1\n2024\n4648.0087\nMGUL AUDI AMC 42 log info verbose 4 MediaSinkFront1024::loadData(): 1 LUM_LastHearedSourceMediaSinkFront 1\n\n\n111164\n2024-01-19 23:34:27.245000\n19\n1\n2024\n4648.6123\nMGUL AUDI AEVE 42 log info verbose 3 MainconnectionStateChange: ConnectionID 72, CS_CONNECTING\n\n\n111166\n2024-01-19 23:34:27.245000\n19\n1\n2024\n4648.6124\n8 MGUL AUDI AMC 42 log info verbose 4 SM MainConn ID=72::isSinkAvailable(): Sink 1024 not avail\n\n\n111554\n2024-01-19 23:34:27.267000\n19\n1\n2024\n4648.6196\nMGUL AUDI AEVE 42 log info verbose 3 MainconnectionStateChange: ConnectionID 70, CS_CONNECTED\n\n\n111628\n2024-01-19 23:34:27.271000\n19\n1\n2024\n4648.621\n1 MGUL VSIP TC 411 nw_trace ipc verbose 2 * (0000:1792) CommandControl(0001).changed_listOfMainConnections_field{"listOfMainConnections":[{"mainConnectionID":70,"sourceID":129,"sinkID":387,"delay":-1,"connectionState":CS_CONNECTED},{"mainConnectionID":71,"sourceID":129,"sinkID":404,"delay":-1,"connectionState":CS_CONNECTING},{"mainConnectionID":72,"sourceID":1,"sinkID":1024,"delay":-1,"connectionState":CS_CONNECTING}]}[OK]\n\n\n459214\n2024-01-19 23:36:16.974000\n19\n1\n2024\n4768.1971\nMGUL AUDI VOLP 42 log info verbose 4 cbCenterStackAudioVolumeButton | Volume change from Centerstack increments: 3\n\n\n459907\n2024-01-19 23:36:17.073000\n19\n1\n2024\n4768.2934\nMGUL AUDI VOLP 42 log info verbose 4 cbCenterStackAudioVolumeButton | Volume change from Centerstack increments: 5\n\n\n460340\n2024-01-19 23:36:17.176000\n19\n1\n2024\n4768.3989\nMGUL AUDI VOLP 42 log info verbose 4 cbCenterStackAudioVolumeButton | Volume change from Centerstack increments: 4\n\n\n461486\n2024-01-19 23:36:17.575000\n19\n1\n2024\n4768.7985\nMGUL AUDI VOLP 42 log info verbose 4 cbCenterStackAudioVolumeButton | Volume change from Centerstack increments: 1\n\n\n120887\n2024-01-19 23:42:23.348000\n19\n1\n2024\n9 5134.619\n3 MGUL AUDI VOLP 42 log info verbose 4 cbCenterStackAudioVolumeButton | Volume change from Centerstack increments: 1\n\n\n121044\n2024-01-19 23:42:23.645000\n19\n1\n2024\n5 5134.916\n6 MGUL AUDI VOLP 42 log info verbose 4 cbCenterStackAudioVolumeButton | Volume change from Centerstack increments: 1\n\n\n121471\n2024-01-19 23:42:24.843000\n19\n1\n2024\n4 5136.114\n9 MGU ...
# C:\Users\40019115\AppData\Roaming\Python\Python311\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# 127.0.0.1 - - [27/Aug/2024 15:12:39] "POST /receive_data_final_final2 HTTP/1.1" 200 -
# output---> - ConnectionID: 70, SourceID: 129, SinkID: 387, ConnectionState: CS_CONNECTED
# - ConnectionID: 71, SourceID: 129, SinkID: 404, ConnectionState: CS_CONNECTING
# - ConnectionID: 72, SourceID: 1, SinkID: 1024, ConnectionState: CS_CONNECTING
# - ConnectionID: 73, SourceID: 3, SinkID: 1024, ConnectionState: CS_CONNECTING
# - ConnectionID: 37, SourceID: 129, SinkID: 387, ConnectionState: CS_CONNECTING
# - ConnectionID: 38, SourceID: 129, SinkID: 404, ConnectionState: CS_CONNECTING
# - ConnectionID: 116, SourceID: 129, SinkID: 387, ConnectionState: CS_CONNECTING
# - ConnectionID: 117, SourceID: 129, SinkID: 404, ConnectionState: CS_CONNECTING
# - ConnectionID: 118, SourceID: 1024, SinkID: 1024, ConnectionState: CS_CONNECTING
